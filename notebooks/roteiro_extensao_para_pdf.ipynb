# %% [markdown]
# # ROTEIRO DE EXTENSÃO
#
# **Projeto:** Análise de Dados Históricos da Segunda Guerra Mundial com Python
#
# **Autoria:** Joseph Alexsander Krescher De Souza, Bernardo de Barros Lobato, Fernando Gentili Magalhães, Lucas Godinho Dias Souza
#
# **Professor(a) Orientador(a):** Felipe Alves
#
# **Ano:** 2026
#
# **Cidade/UF:** Rio de Janeiro - RJ

# %% [markdown]
# ---
#
# # 1. DIAGNÓSTICO E TEORIZAÇÃO

# %% [markdown]
# ## 1.1. Identificação das partes interessadas e parceiros
#
# O projeto é direcionado a **professores de história do ensino médio** e seus **alunos**, que frequentemente encontram dificuldades em tornar o conteúdo da Segunda Guerra Mundial mais visual e quantitativo em sala de aula.
#
# | Público | Perfil |
# |---|---|
# | Professors de história | Graduados em Licenciatura, 25–55 anos, atuantes no ensino público e privado |
# | Estudantes do Ensino Médio | 15–18 anos, sem formação técnica em análise de dados |
#
# A pertinência social do projeto reside na democratização do conhecimento histórico: ao transformar dados brutos e inacessíveis em visualizações compreensíveis, o trabalho cria uma ponte direta entre a tecnologia da informação e o ensino de história. A demanda foi identificada a partir de conversas informais com colegas do curso e da observação de que acervos históricos digitais de alta relevância — como o dataset THOR — são praticamente desconhecidos do público não especializado em dados.

# %% [markdown]
# ## 1.2. Problemática e/ou problemas identificados
#
# **Problema Central:** O conteúdo sobre a Segunda Guerra Mundial é ensinado de forma factual e estática — datas, batalhas, nomes — sem que os estudantes consigam compreender a dimensão quantitativa e estratégica do conflito.
#
# Perguntas que raramente chegam ao estudante do ensino médio:
#
# - Quantas missões aéreas foram realizadas ao longo da guerra?
# - Quais países foram mais bombardeados?
# - Como a intensidade dos bombardeios evoluiu entre 1939 e 1945?
# - Quais foram os alvos mais frequentes dos ataques aéreos?
#
# Grandes acervos históricos digitais — como o **THOR** (*Theater History of Operations Reports*), disponibilizado pelo governo americano via NARA — contêm respostas precisas para essas perguntas, mas são **inacessíveis para quem não possui formação em análise de dados**.
#
# **Pergunta Norteadora:** Como transformar dados históricos brutos em conhecimento visual e acessível para o ensino de história no nível médio?

# %% [markdown]
# ## 1.3. Justificativa
#
# A elaboração deste projeto justifica-se por quatro razões interdependentes:
#
# - O campo da **História Digital** demonstra que a análise quantitativa de registros históricos revela padrões impossíveis de perceber por métodos tradicionais, conforme apontam Moretti (2013) e Guldi & Armitage (2014).
#
# - O curso de **Tecnologia da Informação** forma profissionais que devem aplicar ciência de dados a problemas reais, com impacto social direto — e o ensino de história é um desses problemas reais.
#
# - A **Base Nacional Comum Curricular (BNCC) do Ensino Médio** prevê que o estudante utilize diferentes linguagens — incluindo a digital — para compreender o mundo. Visualizações de dados históricos respondem diretamente a essa demanda curricular.
#
# - O dataset utilizado (**THOR/NARA**) é um registro governamental oficial desclassificado, gerando credibilidade histórica e científica ao trabalho.
#
# Este projeto demonstra que ciência de dados e humanidades não são campos opostos — são perspectivas complementares que, combinadas, produzem conhecimento com maior impacto social e pedagógico.

# %% [markdown]
# ### RESULTADOS E DISCUSSÃO
#
# O que mais me surpreendeu foi reconhecer nos dados lugares que eu havia visitado dentro do jogo. A missão **D-Day** — o desembarque na Normandia, França — aparece claramente nos dados como um dos picos de operações aéreas aliadas de 1944. A missão **Liberation**, que se passa em Paris, também ganhou outro peso ao ver a capital francesa entre as cidades com maior concentração de registros no dataset. E a missão **S.O.E.**, onde o objetivo é destruir um trem blindado alemão carregando foguetes V-2, foi a que mais me chocou: eu duvidei que aquele trem fosse real enquanto jogava — e os dados confirmam que os foguetes V-2 eram alvos militares reais e prioritários. Ver a ficção e a história se cruzando nos números foi uma das experiências mais marcantes do projeto.

# %% [markdown]
# ### METODOLOGIA
#
# Desenvolvi o projeto no Jupyter Notebook com Python, usando bibliotecas como pandas, seaborn, plotly, scikit-learn, wordcloud e pandasql. A etapa mais trabalhosa foi o ETL: dados em inglês técnico-militar, colunas com nulos e formatos inconsistentes que precisavam ser tratados antes de qualquer análise. Houve momentos em que fiquei horas tentando entender como determinadas partes do código funcionavam corretamente. Nesses momentos, recorri à IA como ferramenta de apoio — para explicar trechos de código, ajustar lógicas que não estavam funcionando e corrigir a parte ortográfica do trabalho. Isso agilizou bastante o desenvolvimento e me permitiu avançar sem travar em detalhes técnicos que consumiriam muito mais tempo sozinho. A maior dificuldade foi equilibrar o rigor técnico com uma linguagem acessível para qualquer leitor.

# %% [markdown]
# ---
#
# # 2. PLANEJAMENTO E DESENVOLVIMENTO DO PROJETO

# %% [markdown]
# ## 2.1. Plano de trabalho
#
# O plano de trabalho foi organizado em 3 semanas (iniciado em meados de maio/2026), contemplando todas as etapas do pipeline de ciência de dados e os prazos de entrega de cada item deste roteiro:
#
# | Semana | Período (Aprox.) | Etapa | Entrega |
# |---|---|---|---|
# | **1** | Maio (Semana 2) | Diagnóstico, limpeza dos dados (ETL) e Análise Exploratória (AED Básica) | Seções 1 e 2 do Notebook |
# | **2** | Maio (Semana 3) | Produção dos gráficos (Visualizações) e aplicação de Inteligência Artificial | Seções 3 a 7 do Notebook |
# | **3** | Junho (Semana 1) | Revisão geral, storytelling histórico e redação final | Roteiro de Extensão Completo |

# %% [markdown]
# ## 2.2. Descrição da forma de envolvimento do público participante na formulação do projeto, seu desenvolvimento e avaliação, bem como as estratégias pelo grupo para mobilizá-los
#
# O público-alvo foi considerado de forma indireta durante todas as fases do projeto, por meio das seguintes estratégias:
#
# 1. **Adequação da linguagem:** todo o storytelling do notebook foi redigido em português acessível, garantindo que qualquer aluno do ensino médio ou professor sem formação em programação consiga compreender os resultados apresentados, sem necessidade de conhecimento técnico prévio.
#
# 2. **Validação entre pares:** ao longo do desenvolvimento, foram realizadas conversas informais com colegas de turma sobre a clareza e a legibilidade dos gráficos produzidos — especialmente os gráficos de barras e de setores — para garantir que os resultados comunicassem de forma eficaz.
#
# 3. **Registro e documentação:** o notebook foi estruturado de forma que o produto final pudesse ser apresentado diretamente para o público-alvo, sem necessidade de adaptações posteriores.

# %% [markdown]
# ## 2.3. Grupo de trabalho (descrição da responsabilidade de cada membro)
#
# | Membro | Matrícula | Responsabilidade |
# |---|---|---|
# | **Joseph Alexsander Krescher De Souza** | 202508319501 | Configuração do ambiente Python; tratamento e limpeza dos dados (ETL); desenvolvimento completo do notebook (código + markdown); produção de todas as visualizações; aplicação dos algoritmos de IA (Regressão Logística e K-Means); redação do Roteiro de Extensão. |
# | **Bernardo de Barros Lobato** | 202508319519 | Contribuição na definição da problemática e do público-alvo; apoio na revisão do storytelling e da documentação do notebook; participação na apresentação do projeto para a banca. |
# | **Fernando Gentili Magalhães** | 202309137224 | Apoio na análise exploratória dos dados e na validação dos resultados dos gráficos; contribuição na revisão das seções do Roteiro de Extensão; participação na apresentação do projeto para a banca. |
# | **Lucas Godinho Dias Souza** | 202502303343 | Apoio na interpretação histórica dos dados e na construção do referencial teórico; contribuição na revisão do Relato Coletivo; participação na apresentação do projeto para a banca. |

# %% [markdown]
# ### CONTEXTUALIZAÇÃO
#
# Análise de dados sempre me pareceu interessante, mas os temas mais comuns da área — quantos produtos uma empresa vende por mês, quanto dinheiro um negócio fatura no ano — nunca me prenderam de verdade. O que mudou isso foi *Call of Duty: WWII*. O jogo é baseado em fatos reais da Segunda Guerra Mundial, e acompanhar as operações de perto — especialmente as batalhas aéreas, que no jogo têm um peso visual enorme — despertou uma curiosidade genuína sobre o conflito real por trás daquilo. Quando surgiu a oportunidade de escolher um tema para o projeto, a escolha foi imediata: analisar dados históricos das operações de bombardeio aéreo da Segunda Guerra Mundial com Python. Descobrir que existia um dataset real do governo americano com mais de 178 mil registros dessas missões foi o que confirmou que o projeto faria sentido.

# %% [markdown]
# ## 2.5. Recursos previstos
#
# | Recurso | Tipo | Custo |
# |---|---|---|
# | Jupyter Notebook / Google Colab | Plataforma | R$ 0,00 |
# | Dataset THOR — NARA / data.world | Dado público | R$ 0,00 |
# | Computador e acesso à internet pessoais | Hardware/Infraestrutura | R$ 0,00 |
# | **Total** | | **R$ 0,00** |
#
# Todos os recursos são gratuitos e open source, garantindo que o material possa ser replicado por qualquer estudante ou professor sem custo adicional.

# %% [markdown]
# ## 2.6. Detalhamento técnico do projeto
#
# O produto desenvolvido é um **Jupyter Notebook em Python** estruturado em 7 seções, cobrindo o pipeline completo de ciência de dados:
#
# **Seção 1 — ETL (Extração, Transformação e Carga)**
# Carregamento do dataset THOR (178.281 registros, formato .csv), renomeação de 11 colunas para português, conversão de tipos e documentação da fonte primária.
#
# **Seção 2 — Análise Exploratória de Dados (AED) Básica**
# Inspeção inicial com `head()`, `shape`, `columns`; contagem de missões por país com `groupby`; identificação de valores mínimos e máximos; consulta SQL via pandasql.
#
# **Seção 3 — Histograma e Remoção de Outliers**
# Distribuição da quantidade de aeronaves por missão; identificação e remoção de outliers pelo método IQR (limite: 27 aeronaves por missão).
#
# **Seção 4 — Densidade (KDE) por Ano**
# Estimativa de densidade kernel mostrando a evolução da intensidade das operações entre 1942 e 1945.
#
# **Seção 5 — Classificação: Gráficos de Barras e Setores**
# Total de missões por país aliado (barras); distribuição percentual dos tipos de alvo bombardeado (pizza/setores).
#
# **Seção 6 — Evolução Temporal**
# Gráfico de linha mostrando o total de missões por ano (1939–1945), com storytelling destacando o pico de 1944 associado à Operação Overlord (Dia D).
#
# **Seção 7 — Análises Avançadas com Inteligência Artificial**
# - *Nuvem de Palavras:* cidades mais bombardeadas em destaque (Berlim, Hamburgo, Colônia).
# - *Regras de Associação (Apriori):* 6 regras identificadas entre país, tipo de missão e tipo de alvo.
# - *Clusterização (K-Means):* 3 clusters de missões identificados por intensidade e perfil operacional.
#
# **Bibliotecas utilizadas:**
#
# | Biblioteca | Finalidade |
# |---|---|
# | `pandas` | Manipulação e análise de dados tabulares |
# | `numpy` | Operações matemáticas e estatísticas |
# | `matplotlib` / `seaborn` | Visualizações estáticas |
# | `plotly` | Gráficos interativos |
# | `wordcloud` | Nuvem de palavras |
# | `mlxtend` | Algoritmo Apriori (regras de associação) |
# | `scikit-learn` | Algoritmo K-Means (clusterização) |
# | `pandasql` | Consultas SQL sobre DataFrames |
#
# **Fonte dos dados:** THOR (*Theater History of Operations Reports*) — acervo desclassificado pelo *National Archives and Records Administration* (NARA), EUA. Disponível em: https://data.world/datamil/world-war-ii-thor-data

# %% [markdown]
# ---
#
# # 3. ENCERRAMENTO DO PROJETO

# %% [markdown]
# ## 3.1. Relato Coletivo: Considerações do grupo sobre o atingimento dos objetivos sociocomunitários estabelecidos para o projeto.
#
# O grupo avalia que os objetivos propostos na Seção 1.4 foram plenamente atingidos ao longo do desenvolvimento deste projeto de extensão.
#
# Conseguimos transformar mais de 178 mil registros brutos de operações militares da Segunda Guerra Mundial em um material educacional visual, acessível e tecnicamente rigoroso. O Jupyter Notebook produzido cobre todo o pipeline de ciência de dados — da ingestão e limpeza dos dados até a aplicação de algoritmos de Machine Learning — e está disponível gratuitamente no GitHub como recurso educacional aberto.
#
# Do ponto de vista sociocomunitário, acreditamos que o projeto contribui concretamente para aproximar o ensino de história do ensino médio às ferramentas de análise de dados modernas, permitindo que professores e alunos compreendam a dimensão quantitativa e estratégica do conflito de forma visual e interativa.
#
# A experiência demonstrou que Python e Big Data não são ferramentas exclusivas do mercado corporativo: elas podem ser utilizadas para recuperar e democratizar o conhecimento histórico, tornando-o mais acessível à comunidade em geral.
#
# **[ PREENCHA AQUI: Acrescente a reação da banca / do professor durante a apresentação e qualquer feedback recebido após a entrega. ]**

# %% [markdown]
# ## 3.2. Avaliação de reação da parte interessada
#
# **[ PREENCHA ESTE CAMPO ]**
#
# *Descreva aqui como foi a avaliação de reação do seu público participante. Sugestões do que abordar:*
#
# - *Como foi a apresentação do projeto para o professor / banca?*
# - *Os gráficos foram considerados visuais e de fácil compreensão?*
# - *Houve algum feedback positivo ou crítica que vale registrar?*
# - *Se possível, mencione depoimentos ou reações dos colegas ao ver os resultados.*

# %% [markdown]
# ## 3.3. Relato de Experiência Individual
#
# **Autoria:** Joseph Alexsander Krescher De Souza, Bernardo de Barros Lobato, Fernando Gentili Magalhães, Joseph Alexsander Krescher De Souza, Bernardo de Barros Lobato, Fernando Gentili Magalhães, Lucas Godinho Dias Souza

# %% [markdown]
# ### CONTEXTUALIZAÇÃO
#
# Análise de dados sempre me pareceu interessante, mas os temas mais comuns da área — quantos produtos uma empresa vende por mês, quanto dinheiro um negócio fatura no ano — nunca me prenderam de verdade. O que mudou isso foi *Call of Duty: WWII*. O jogo é baseado em fatos reais da Segunda Guerra Mundial, e acompanhar as operações de perto — especialmente as batalhas aéreas, que no jogo têm um peso visual enorme — despertou uma curiosidade genuína sobre o conflito real por trás daquilo. Quando surgiu a oportunidade de escolher um tema para o projeto, a escolha foi imediata: analisar dados históricos das operações de bombardeio aéreo da Segunda Guerra Mundial com Python. Descobrir que existia um dataset real do governo americano com mais de 178 mil registros dessas missões foi o que confirmou que o projeto faria sentido.

# %% [markdown]
# ### METODOLOGIA
#
# Desenvolvi o projeto no Jupyter Notebook com Python, usando bibliotecas como pandas, seaborn, plotly, scikit-learn, wordcloud e pandasql. A etapa mais trabalhosa foi o ETL: dados em inglês técnico-militar, colunas com nulos e formatos inconsistentes que precisavam ser tratados antes de qualquer análise. Houve momentos em que fiquei horas tentando entender como determinadas partes do código funcionavam corretamente. Nesses momentos, recorri à IA como ferramenta de apoio — para explicar trechos de código, ajustar lógicas que não estavam funcionando e corrigir a parte ortográfica do trabalho. Isso agilizou bastante o desenvolvimento e me permitiu avançar sem travar em detalhes técnicos que consumiriam muito mais tempo sozinho. A maior dificuldade foi equilibrar o rigor técnico com uma linguagem acessível para qualquer leitor.

# %% [markdown]
# ### RESULTADOS E DISCUSSÃO
#
# O que mais me surpreendeu foi reconhecer nos dados lugares que eu havia visitado dentro do jogo. A missão **D-Day** — o desembarque na Normandia, França — aparece claramente nos dados como um dos picos de operações aéreas aliadas de 1944. A missão **Liberation**, que se passa em Paris, também ganhou outro peso ao ver a capital francesa entre as cidades com maior concentração de registros no dataset. E a missão **S.O.E.**, onde o objetivo é destruir um trem blindado alemão carregando foguetes V-2, foi a que mais me chocou: eu duvidei que aquele trem fosse real enquanto jogava — e os dados confirmam que os foguetes V-2 eram alvos militares reais e prioritários. Ver a ficção e a história se cruzando nos números foi uma das experiências mais marcantes do projeto.

# %% [markdown]
# ### REFLEXÃO APROFUNDADA
#
# Esse projeto me mostrou que programação é muito mais difícil do que parece de fora, especialmente no começo. Há um ponto em que você olha para o código e não entende por onde começar. Mas quando o trabalho vai tomando forma e os resultados aparecem na tela — gráficos, padrões, análises que fazem sentido — a sensação é incrível, vale cada hora de dificuldade. Além da parte técnica, os dados me fizeram refletir bastante sobre o conflito em si. Pela escala das operações americanas que aparecem nos registros, fica difícil imaginar o desfecho da guerra sem a entrada dos Estados Unidos. Na minha opinião, Os dados analisados evidenciam a grande escala da participação americana no conflito, reforçando sua relevância estratégica para o resultado da guerra. Essa é uma conclusão minha, mas os dados deixam essa dimensão muito mais visível do que qualquer livro texto.

# %% [markdown]
# ### CONSIDERAÇÕES FINAIS
#
# Concluído o projeto, fica claro que o que foi feito aqui é apenas o ponto de partida. A evolução natural seria transformar o notebook estático em um **dashboard interativo** — uma aplicação web onde qualquer professor pudesse, sem saber programar, filtrar os dados por país, ano ou tipo de alvo e gerar os gráficos em tempo real. Tecnologias como Streamlit ou Power BI permitiriam isso sem grande complexidade adicional.
#
# Outra possibilidade seria ampliar a análise para conflitos que fazem parte da nossa própria história — como a atuação da Força Expedicionária Brasileira (FEB) na Itália, a Guerra do Paraguai ou até mesmo conflitos internos como a Guerra de Canudos. Criar mapas interativos e linhas do tempo comparativas sobre a história militar e civil do Brasil tornaria o material ainda mais rico e próximo da realidade dos alunos, aplicando a mesma tecnologia em dados nacionais.
#
# Do ponto de vista da minha formação, esse projeto consolidou na prática o que a faculdade ensina na teoria. Pandas, SQL, algoritmos de IA — tudo isso saiu do slide e foi para o código resolvendo um problema real. A análise de dados deixou de ser abstrata e passou a ser uma ferramenta que eu me imagino usando profissionalmente. Mais do que isso, aprendi que programação não precisa ser só sobre sistemas corporativos e relatórios financeiros — ela pode ser usada para contar histórias, preservar memória histórica e tornar o conhecimento mais acessível para qualquer pessoa.

# %% [markdown]
# ---
#
# ## Referências Bibliográficas
#
# BRASIL. **Base Nacional Comum Curricular — Ensino Médio**. Brasília: MEC, 2018.
#
# CHARTIER, R. **A Ordem dos Livros**. Brasília: Editora UnB, 1998.
#
# GULDI, J.; ARMITAGE, D. **The History Manifesto**. Cambridge: Cambridge University Press, 2014.
#
# McKINNEY, W. **Python for Data Analysis**. 2. ed. Sebastopol: O'Reilly Media, 2017.
#
# MORETTI, F. **Distant Reading**. London: Verso Books, 2013.
#
# NARA. **THOR — Theater History of Operations Reports: WWII**. Disponível em: https://data.world/datamil/world-war-ii-thor-data. Acesso em: maio 2026.
#
# TUKEY, J. W. **Exploratory Data Analysis**. Reading: Addison-Wesley, 1977.
